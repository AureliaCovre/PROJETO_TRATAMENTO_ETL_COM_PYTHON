# %% [markdown]
# ETAPA DE LIMPEZA DOS DADOS

# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=["ocorrencia_dia"],dayfirst=True)

# %% [markdown]
# Aqui estamos puxando a linha 1 da coluna "ocorrencia_cidade"

# %%
df.loc[1,"ocorrencia_cidade"]
# Out:
# 'GUARULHOS'

# %% [markdown]
# Aqui estamos puxando as linhas de indices 1 e até 3

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %% [markdown]
# Ps. aqui ele puxou as linhas 10 e 40, se colocasse : como separador ele iria buscar da 10 até a 40.

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 ****     2012-01-09
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 40        13:55:00                    0

# %%
df.loc[:,"ocorrencia_cidade"]
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %% [markdown]
# VERIFICANDO SE OS DADOS SÃO UNICOS

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# Aqui estamos definindo que o index é o mesmo que o codigo_ocorrencia

# %%
df.set_index("codigo_ocorrencia", inplace=True)

# %%
df.loc[45331]
# Out:
# codigo_ocorrencia2                        45331
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                     GUARULHOS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBGR
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        13:44:00
# total_recomendacoes                           3
# Name: 45331, dtype: object

# %% [markdown]
# Resetando o indice do df e voltando ao original.

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                 ****     2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ALTERANDO OS DADOS DO DF

# %% [markdown]
# Aqui alteranos todos os dados do indice 1 para o valor 20

# %%
df.loc[1]=20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1                  20                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
#
#    total_recomendacoes
# 0                    0
# 1                   20

# %% [markdown]
# Alterando os dados da coluna total recomendações para 10

# %%
df.loc[:,"total_recomendacoes"]=10

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                     20                       20                20
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# CRIANDO BKP DA COLUNA OCORRENCIA UF (UMA COLUNA COPIA PARA FAZER ALTERAÇÕES E TESTES SEM MODIFICAR A ORIGINAL)

# %%
df[("ocorrencia_uf_bkp")]= df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                     20                       20                20
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# ALTERANDO A OCORRENCIA CLASSIFICAÇÃO DE SP PARA GRAVE

# %%
df.loc[df.ocorrencia_uf == "SP", ["ocorrencia_classificacao"]] = "GRAVE"

# %%
df.loc[df.ocorrencia_uf == "SP"]
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 3                  45401                    GRAVE      SÃO SEBASTIÃO
# 5                  52243                    GRAVE            UBATUBA
# 6                  50713                    GRAVE           CAMPINAS
# 13                 45408                    GRAVE           ELDORADO
# 26                 45410                    GRAVE  BRAGANÇA PAULISTA
# ...                  ...                      ...                ...
# 5148               80441                    GRAVE  BRAGANÇA PAULISTA
# 5157               80453                    GRAVE           CAMPINAS
# 5158               80454                    GRAVE          ARAÇATUBA
# 5161               80456                    GRAVE          SÃO PAULO
# 5163               80452                    GRAVE            MARACAÍ
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo == "****", ["ocorrencia_aerodromo"]] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1                  20                       20                20
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                    GRAVE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
# 2            RS                 <NA>  2012-01-06 00:00:00        13:00:00
# 3            SP                 <NA>  2012-01-06 00:00:00        17:00:00
# 4            RS                 <NA>  2012-01-06 00:00:00        16:30:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RS
# 1                   10                20
# ...

# %%
df.replace(["**","###!", "####","****","*****", "NULL" ], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                     20                       20                20
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                    GRAVE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                    GRAVE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# Para saber quantos NA temos

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              2
# dtype: int64

# %% [markdown]
# Aqui estamos alterando os dados nulos para 10

# %%
df.fillna(10,inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# ocorrencia_uf_bkp           0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1                  20                       20                20
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                    GRAVE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA  2012-01-05 00:00:00        20:27:00
# 1            20                   20                   20              20
# 2            RS                   10  2012-01-06 00:00:00        13:00:00
# 3            SP                   10  2012-01-06 00:00:00        17:00:00
# 4            RS                   10  2012-01-06 00:00:00        16:30:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RS
# 1                   10                20
# ...

# %% [markdown]
# Aqui estamos alterando todos os valores 10 para NA

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes         5167
# ocorrencia_uf_bkp              2
# dtype: int64

# %% [markdown]
# Alterando os valores nulos apenas da coluna "total_recomendacoes" para 10

# %%
df.fillna(value={"total_recomendacoes":10}, inplace=True)

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                 52242                INCIDENTE      PORTO ALEGRE
# 1                    20                       20                20
# 2                 45333                 ACIDENTE            VIAMÃO
# 3                 45401                    GRAVE     SÃO SEBASTIÃO
# 4                 45407                 ACIDENTE          SÃO SEPÉ
# ...                 ...                      ...               ...
# 5162              80458                 ACIDENTE             JATAÍ
# 5163              80452                    GRAVE           MARACAÍ
# 5164              80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165              80460                INCIDENTE          CURITIBA
# 5166              80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA  2012-01-05 00:00:00        20:27:00
# ...

# %%
df["total_recomendacoes_bkp"] = df.total_recomendacoes

# %% [markdown]
# Excluindo a coluna bkp que criamos no dataframe, AXIS ele entende que é a coluna

# %%
df.drop(["total_recomendacoes_bkp"], axis= 1, inplace=True)

# %%
df.head()
# Out:
#   codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0              52242                INCIDENTE      PORTO ALEGRE            RS
# 1                 20                       20                20            20
# 2              45333                 ACIDENTE            VIAMÃO            RS
# 3              45401                    GRAVE     SÃO SEBASTIÃO            SP
# 4              45407                 ACIDENTE          SÃO SEPÉ            RS
#
#   ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0                 SBPA  2012-01-05 00:00:00        20:27:00
# 1                   20                   20              20
# 2                 <NA>  2012-01-06 00:00:00        13:00:00
# 3                 <NA>  2012-01-06 00:00:00        17:00:00
# 4                 <NA>  2012-01-06 00:00:00        16:30:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RS
# 1                   10                20
# ...

# %% [markdown]
# EXCLUINDO O NA APENAS DA COLUNA "ocorrencia_uf"

# %%
df.dropna(subset=["ocorrencia_uf"])
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                 52242                INCIDENTE      PORTO ALEGRE
# 1                    20                       20                20
# 2                 45333                 ACIDENTE            VIAMÃO
# 3                 45401                    GRAVE     SÃO SEBASTIÃO
# 4                 45407                 ACIDENTE          SÃO SEPÉ
# ...                 ...                      ...               ...
# 5162              80458                 ACIDENTE             JATAÍ
# 5163              80452                    GRAVE           MARACAÍ
# 5164              80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165              80460                INCIDENTE          CURITIBA
# 5166              80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA  2012-01-05 00:00:00        20:27:00
# ...
